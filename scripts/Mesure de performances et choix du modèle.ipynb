# %%
# !pip install pywaffle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 16.6 MB/s eta 0:00:00
# ...

# %%
# --- Importation des librairies ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_profiling
import seaborn as sns
import warnings
import os
import yellowbrick
import scipy.cluster.hierarchy as shc
import matplotlib.patches as patches

from matplotlib.patches import Rectangle
from pandas_profiling import ProfileReport
from pywaffle import Waffle
from math import isnan
from random import sample
from numpy.random import uniform
from sklearn.neighbors import NearestNeighbors
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics import davies_bouldin_score, silhouette_score, calinski_harabasz_score
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
from yellowbrick.style import set_palette
from yellowbrick.contrib.wrapper import wrap

# --- Configuration des librairies ---
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.dpi'] = 600
sns.set(rc = {'axes.facecolor': '#FBFBFB', 'figure.facecolor': '#FBFBFB'})
class clr:
    start = '\033[93m'+'\033[1m'
    color = '\033[93m'
    end = '\033[0m'

# %% [markdown]
# ## <div class="header2">7.4 | Evaluation des modèles</div>
# <div class="explain-box">
#
# </div>

# %%
table_de_comparaison_des_modeles = pd.read_excel("../data/comparaison_des_modeles.xlsx")
print(clr.start+'.: Comparaison de la précision des modèles :.'+clr.end)
print(clr.color+'*' * 32+clr.end)
table_de_comparaison_des_modeles.sort_values(by='Modèles', ascending=False).style.background_gradient(cmap='inferno_r').hide_index().set_properties(**{'font-family': 'Segoe UI'})
# Out:
# .: Comparaison de la précision des modèles :.
# ********************************
# <style type="text/css">
# #T_59cad_row0_col0, #T_59cad_row1_col0, #T_59cad_row2_col0 {
#   font-family: Segoe UI;
# }
# #T_59cad_row0_col1, #T_59cad_row1_col3, #T_59cad_row2_col2 {
#   background-color: #fcffa4;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_59cad_row0_col2 {
#   background-color: #f1ef75;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_59cad_row0_col3, #T_59cad_row1_col1, #T_59cad_row1_col2 {
#   background-color: #000004;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_59cad_row2_col1 {
#   background-color: #f9c932;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_59cad_row2_col3 {
#   background-color: #420a68;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_59cad" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_59cad_level0_col0" class="col_heading level0 col0" >Modèles</th>
# ...

# %% [markdown]
# <div class="explain-box">
#   La table ci-dessus montre que l'algorithme K-Means a l'indice de Davies-Bouldin le plus bas par rapport aux deux autres algorithmes, <br>il peut donc être conclu que <b>K-Means a une qualité de clustering décente</b> par rapport aux deux autres algorithmes.<br><br> Cependant, selon le score de silhouette, <b>K-Means a le deuxième score de silhouette le plus élevé</b> (il y a des clusters chevauchants formés en utilisant cet algorithme).<br><br>
# De plus, le clustering en utilisant l'<b>algorithme de clustering hiérarchique a des résultats de qualité de clustering similaires à K-Means</b>. L'indice de Davies-Bouldin est légèrement plus élevé et le score de silhouette est légèrement plus bas que K-Means. <br><br>Enfin, le clustering en utilisant <b>DBSCAN a le pire indice de Davies-Bouldin mais le meilleur score de silhouette par rapport aux autres algorithmes</b>.<br><br>
# À partir des résultats de l'indice de Calinski-Harabasz, on peut voir que <b>K-Means a l'indice le plus élevé</b> par rapport aux autres algorithmes. <br><br>Cela indique que <mark><b>K-Means fonctionne mieux et est plus dense que les autres algorithmes</b></mark>.<br><br>
# Il peut être conclu que <mark><b>K-Means a la meilleure qualité de segmentation des trois algorithmes</b></mark> en raison de la plus faible valeur de l'indice Davies-Bouldin et des clusters légèrement meilleurs que la classification hiérarchique(CAH). <br><br>La prochaine étape consiste à réaliser un <mark><b>profilage</b></mark> pour <b>identifier les caractéristiques de chaque segment</b>.
# </div>
